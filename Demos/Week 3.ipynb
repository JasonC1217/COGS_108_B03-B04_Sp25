# %% [markdown]
# # Week 3 Demo:
# ## Data wrangling
# COGS108, SP25, Week 3

# %% [markdown]
# ### First, let's import the packages we need:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Then, let's load our data:

# %% [markdown]
# We load the dataset directly from FiveThirtyEight’s GitHub repository using `pandas.read_csv()`:
#
# ```python
# import pandas as pd
#
# # Load the steak risk survey dataset into a DataFrame called 'survey'
# survey = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/steak-survey/steak-risk-survey.csv")
# ```

# %%
survey = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/steak-survey/steak-risk-survey.csv")

# %%
survey
# Out:
#      RespondentID  \
# 0             NaN
# 1    3.237566e+09
# 2    3.234982e+09
# 3    3.234973e+09
# 4    3.234972e+09
# ..            ...
# 546  3.234762e+09
# 547  3.234762e+09
# 548  3.234761e+09
# 549  3.234761e+09
# 550  3.234760e+09
#
#     Consider the following hypothetical situations: <br>In Lottery A, you have a 50% chance of success, with a payout of $100. <br>In Lottery B, you have a 90% chance of success, with a payout of $20. <br><br>Assuming you have $10 to bet, would you play Lottery A or Lottery B?  \
# 0                                             Response
# 1                                            Lottery B
# 2                                            Lottery A
# 3                                            Lottery A
# 4                                            Lottery B
# ..                                                 ...
# 546                                          Lottery B
# 547                                          Lottery A
# 548                                          Lottery A
# 549                                          Lottery A
# 550                                          Lottery B
#
#     Do you ever smoke cigarettes? Do you ever drink alcohol?  \
# 0                        Response                   Response
# 1                             NaN                        NaN
# 2                              No                        Yes
# 3                              No                        Yes
# 4                             Yes                        Yes
# ..                            ...                        ...
# 546                            No                         No
# 547                            No                        Yes
# 548                           Yes                        Yes
# 549                            No                        Yes
# 550                           Yes                        Yes
#
#     Do you ever gamble? Have you ever been skydiving?  \
# 0              Response                      Response
# 1                   NaN                           NaN
# 2                    No                            No
# 3                   Yes                            No
# 4                   Yes                            No
# ..                  ...                           ...
# 546                  No                            No
# 547                  No                           Yes
# 548                 Yes                            No
# 549                 Yes                            No
# 550                 Yes                            No
#
#     Do you ever drive above the speed limit?  \
# 0                                   Response
# 1                                        NaN
# 2                                         No
# 3                                        Yes
# 4                                        Yes
# ..                                       ...
# 546                                      Yes
# 547                                      Yes
# 548                                      Yes
# 549                                      Yes
# 550                                      Yes
#
#     Have you ever cheated on your significant other? Do you eat steak?  \
# 0                                           Response          Response
# 1                                                NaN               NaN
# 2                                                 No               Yes
# 3                                                Yes               Yes
# 4                                                Yes               Yes
# ..                                               ...               ...
# 546                                               No               Yes
# 547                                               No                No
# 548                                               No               Yes
# 549                                              Yes                No
# 550                                               No               Yes
#
#     How do you like your steak prepared?    Gender       Age  \
# 0                               Response  Response  Response
# 1                                    NaN       NaN       NaN
# 2                            Medium rare      Male      > 60
# 3                                   Rare      Male      > 60
# 4                                 Medium      Male      > 60
# ..                                   ...       ...       ...
# 546                          Medium rare    Female     18-29
# 547                                  NaN    Female      > 60
# 548                          Medium rare      Male     30-44
# 549                                  NaN    Female     45-60
# 550                               Medium      Male     18-29
#
#       Household Income                         Education  \
# 0             Response                          Response
# 1                  NaN                               NaN
# 2    $50,000 - $99,999  Some college or Associate degree
# 3            $150,000+                   Graduate degree
# 4    $50,000 - $99,999                   Bachelor degree
# ..                 ...                               ...
# 546  $25,000 - $49,999                High school degree
# 547  $50,000 - $99,999  Some college or Associate degree
# 548  $50,000 - $99,999  Some college or Associate degree
# 549  $50,000 - $99,999  Some college or Associate degree
# 550       $0 - $24,999                               NaN
#
#     Location (Census Region)
# 0                   Response
# 1                        NaN
# 2         East North Central
# 3             South Atlantic
# 4                New England
# ..                       ...
# 546           South Atlantic
# 547                 Mountain
# 548           South Atlantic
# 549                  Pacific
# 550                 Mountain
#
# [551 rows x 15 columns]

# %% [markdown]
# ### Basic Pandas Operations:

# %%
# Show the first 5 rows of the data frame:

survey.head()
# Out:
#    RespondentID  \
# 0           NaN
# 1  3.237566e+09
# 2  3.234982e+09
# 3  3.234973e+09
# 4  3.234972e+09
#
#   Consider the following hypothetical situations: <br>In Lottery A, you have a 50% chance of success, with a payout of $100. <br>In Lottery B, you have a 90% chance of success, with a payout of $20. <br><br>Assuming you have $10 to bet, would you play Lottery A or Lottery B?  \
# 0                                           Response
# 1                                          Lottery B
# 2                                          Lottery A
# 3                                          Lottery A
# 4                                          Lottery B
#
#   Do you ever smoke cigarettes? Do you ever drink alcohol?  \
# 0                      Response                   Response
# 1                           NaN                        NaN
# 2                            No                        Yes
# 3                            No                        Yes
# 4                           Yes                        Yes
#
#   Do you ever gamble? Have you ever been skydiving?  \
# 0            Response                      Response
# 1                 NaN                           NaN
# 2                  No                            No
# 3                 Yes                            No
# 4                 Yes                            No
#
#   Do you ever drive above the speed limit?  \
# 0                                 Response
# 1                                      NaN
# 2                                       No
# 3                                      Yes
# 4                                      Yes
#
#   Have you ever cheated on your significant other? Do you eat steak?  \
# 0                                         Response          Response
# 1                                              NaN               NaN
# 2                                               No               Yes
# 3                                              Yes               Yes
# 4                                              Yes               Yes
#
#   How do you like your steak prepared?    Gender       Age   Household Income  \
# 0                             Response  Response  Response           Response
# 1                                  NaN       NaN       NaN                NaN
# 2                          Medium rare      Male      > 60  $50,000 - $99,999
# 3                                 Rare      Male      > 60          $150,000+
# 4                               Medium      Male      > 60  $50,000 - $99,999
#
#                           Education Location (Census Region)
# 0                          Response                 Response
# 1                               NaN                      NaN
# 2  Some college or Associate degree       East North Central
# 3                   Graduate degree           South Atlantic
# 4                   Bachelor degree              New England

# %%
# Show descriptive statistics of column "Age":

survey['Age'].describe()
# Out:
# count       515
# unique        5
# top       45-60
# freq        140
# Name: Age, dtype: object

# %% [markdown]
# #### What is iloc in pandas?
# ```iloc``` stands for "integer-location based indexing" and is a pandas method used to select rows and columns from a ```DataFrame``` or ```Series``` by position, not by label.

# %% [markdown]
# #### Syntax:
# ```python
# DataFrame.iloc[row_index, column_index]
# ```
# - ```row_index```: the row number you want (e.g., ```0``` is the first row)
# - ```column_index```: the column number you want (e.g., ```1``` is the second column)

# %% [markdown]
# #### Examples:
# - ```survey.iloc[0]```         Returns the first row (as a Series)
# - ```survey.iloc[0, 2]```      Returns the value at first row, third column
# - ```survey.iloc[0:3]```       Returns rows 0, 1, 2
# - ```survey.iloc[:, 1]```      Returns the second column (all rows)
# - ```survey.iloc[[0, 2], [1, 3]]```  Returns values from rows 0 & 2, columns 1 & 3

# %%
# Show first row of data frame:
survey.iloc[0]
# Out:
# RespondentID                                                                                                                                                                                                                                                                              NaN
# Consider the following hypothetical situations: <br>In Lottery A, you have a 50% chance of success, with a payout of $100. <br>In Lottery B, you have a 90% chance of success, with a payout of $20. <br><br>Assuming you have $10 to bet, would you play Lottery A or Lottery B?    Response
# Do you ever smoke cigarettes?                                                                                                                                                                                                                                                        Response
# Do you ever drink alcohol?                                                                                                                                                                                                                                                           Response
# Do you ever gamble?                                                                                                                                                                                                                                                                  Response
# Have you ever been skydiving?                                                                                                                                                                                                                                                        Response
# Do you ever drive above the speed limit?                                                                                                                                                                                                                                             Response
# Have you ever cheated on your significant other?                                                                                                                                                                                                                                     Response
# Do you eat steak?                                                                                                                                                                                                                                                                    Response
# How do you like your steak prepared?                                                                                                                                                                                                                                                 Response
# Gender                                                                                                                                                                                                                                                                               Response
# Age                                                                                                                                                                                                                                                                                  Response
# Household Income                                                                                                                                                                                                                                                                     Response
# Education                                                                                                                                                                                                                                                                            Response
# Location (Census Region)                                                                                                                                                                                                                                                             Response
# Name: 0, dtype: object

# %%
# show first column of data frame:
survey.iloc[:,0]
# Out:
# 0               NaN
# 1      3.237566e+09
# 2      3.234982e+09
# 3      3.234973e+09
# 4      3.234972e+09
#            ...
# 546    3.234762e+09
# 547    3.234762e+09
# 548    3.234761e+09
# 549    3.234761e+09
# 550    3.234760e+09
# Name: RespondentID, Length: 551, dtype: float64

# %%
# Show list of column names:
list(survey)
survey.columns
# Out:
# Index(['RespondentID',
#        'Consider the following hypothetical situations: <br>In Lottery A, you have a 50% chance of success, with a payout of $100. <br>In Lottery B, you have a 90% chance of success, with a payout of $20. <br><br>Assuming you have $10 to bet, would you play Lottery A or Lottery B?',
#        'Do you ever smoke cigarettes?', 'Do you ever drink alcohol?',
#        'Do you ever gamble?', 'Have you ever been skydiving?',
#        'Do you ever drive above the speed limit?',
#        'Have you ever cheated on your significant other?', 'Do you eat steak?',
#        'How do you like your steak prepared?', 'Gender', 'Age',
#        'Household Income', 'Education', 'Location (Census Region)'],
#       dtype='object')

# %% [markdown]
# #### Rename DataFrame Columns
#
# We can assign a new list of column names to the `survey` DataFrame using the `.columns` attribute:
#
# ```python
# # Rename all columns with a new list of names
# survey.columns = a_list

# %% [markdown]
# #### Rename a Single Column
#
# We can also use `.rename()` with a dictionary to change the name of one column:
#
# ```python
# # Rename the column 'Answer' to 'response'
# survey = survey.rename(columns={'Answer': 'response'})

# %%
# rename columns:

survey.columns = ['ID','Answer','smoking','alcohol','gambling',
 'skydiving','speeding', 'cheated',
 'steak', 'steak_preference','gender',
 'age', 'income', 'education', 'region']

survey
# Out:
#                ID     Answer   smoking   alcohol  gambling skydiving  \
# 0             NaN   Response  Response  Response  Response  Response
# 1    3.237566e+09  Lottery B       NaN       NaN       NaN       NaN
# 2    3.234982e+09  Lottery A        No       Yes        No        No
# 3    3.234973e+09  Lottery A        No       Yes       Yes        No
# 4    3.234972e+09  Lottery B       Yes       Yes       Yes        No
# ..            ...        ...       ...       ...       ...       ...
# 546  3.234762e+09  Lottery B        No        No        No        No
# 547  3.234762e+09  Lottery A        No       Yes        No       Yes
# 548  3.234761e+09  Lottery A       Yes       Yes       Yes        No
# 549  3.234761e+09  Lottery A        No       Yes       Yes        No
# 550  3.234760e+09  Lottery B       Yes       Yes       Yes        No
#
#      speeding   cheated     steak steak_preference    gender       age  \
# 0    Response  Response  Response         Response  Response  Response
# 1         NaN       NaN       NaN              NaN       NaN       NaN
# 2          No        No       Yes      Medium rare      Male      > 60
# 3         Yes       Yes       Yes             Rare      Male      > 60
# 4         Yes       Yes       Yes           Medium      Male      > 60
# ..        ...       ...       ...              ...       ...       ...
# 546       Yes        No       Yes      Medium rare    Female     18-29
# 547       Yes        No        No              NaN    Female      > 60
# 548       Yes        No       Yes      Medium rare      Male     30-44
# 549       Yes       Yes        No              NaN    Female     45-60
# 550       Yes        No       Yes           Medium      Male     18-29
#
#                 income                         education              region
# 0             Response                          Response            Response
# 1                  NaN                               NaN                 NaN
# 2    $50,000 - $99,999  Some college or Associate degree  East North Central
# 3            $150,000+                   Graduate degree      South Atlantic
# 4    $50,000 - $99,999                   Bachelor degree         New England
# ..                 ...                               ...                 ...
# 546  $25,000 - $49,999                High school degree      South Atlantic
# 547  $50,000 - $99,999  Some college or Associate degree            Mountain
# 548  $50,000 - $99,999  Some college or Associate degree      South Atlantic
# 549  $50,000 - $99,999  Some college or Associate degree             Pacific
# 550       $0 - $24,999                               NaN            Mountain
#
# [551 rows x 15 columns]

# %% [markdown]
# #### Counting Rows with Null Values
#
# The following line of code counts how many rows in the `survey` DataFrame contain **at least one missing (null) value**:
#
# ```python
# null_rows = survey.isnull().any(axis=1).sum()

# %% [markdown]
# - ```survey.isnull()``` returns a ```DataFrame``` of the same shape where: each value is ```True``` if it's missing (```NaN```), otherwise ```False```;
# - ```.any(axis=1)``` checks across each row (because ```axis=1```) to see if any column has a ```True``` (i.e., is ```null```). It returns a series of booleans: ```True``` if the row has at least one ```null``` value, ```False``` otherwise.
# - ```.sum()``` adds up the number of ```True``` values in the series. Since ```True``` is treated as ```1```, and ```False``` as ```0```, this gives the total number of rows with missing values.

# %%
# Check the number of rows that cotains null value:

null_rows = survey.isnull().any(axis = 1).sum()

print(null_rows)
# Out:
# 220

# %% [markdown]
# #### Drop Rows with Missing Values
#
# We can remove all rows from the `survey` DataFrame that contain **at least one null (NaN) value** using the `dropna()` method:
#
# Since we wanna drop rows that contain at least one null value, we use:
# - ```axis=0``` to specify that we are dropping rows (not columns)
# - ```how='any'``` means drop the row if **any** column is null
#
# ```python
# cleaned_table = survey.dropna(axis=0, how='any')

# %%
# Drop all rows that have at least one null values:

cleaned_table = survey.dropna(axis = 0, how = 'any')

cleaned_table
# Out:
#                ID     Answer smoking alcohol gambling skydiving speeding  \
# 2    3.234982e+09  Lottery A      No     Yes       No        No       No
# 3    3.234973e+09  Lottery A      No     Yes      Yes        No      Yes
# 4    3.234972e+09  Lottery B     Yes     Yes      Yes        No      Yes
# 5    3.234959e+09  Lottery B      No     Yes       No        No      Yes
# 6    3.234955e+09  Lottery A      No      No       No        No      Yes
# ..            ...        ...     ...     ...      ...       ...      ...
# 543  3.234763e+09  Lottery A      No     Yes      Yes        No      Yes
# 544  3.234762e+09  Lottery B      No     Yes       No        No      Yes
# 545  3.234762e+09  Lottery A      No      No      Yes        No      Yes
# 546  3.234762e+09  Lottery B      No      No       No        No      Yes
# 548  3.234761e+09  Lottery A     Yes     Yes      Yes        No      Yes
#
#     cheated steak steak_preference  gender    age               income  \
# 2        No   Yes      Medium rare    Male   > 60    $50,000 - $99,999
# 3       Yes   Yes             Rare    Male   > 60            $150,000+
# 4       Yes   Yes           Medium    Male   > 60    $50,000 - $99,999
# 5       Yes   Yes           Medium    Male   > 60    $50,000 - $99,999
# 6        No   Yes      Medium rare    Male  18-29         $0 - $24,999
# ..      ...   ...              ...     ...    ...                  ...
# 543      No   Yes      Medium rare    Male   > 60    $50,000 - $99,999
# 544      No   Yes      Medium Well  Female   > 60  $100,000 - $149,999
# 545      No   Yes      Medium Well    Male  30-44    $50,000 - $99,999
# 546      No   Yes      Medium rare  Female  18-29    $25,000 - $49,999
# 548      No   Yes      Medium rare    Male  30-44    $50,000 - $99,999
#
#                             education              region
# 2    Some college or Associate degree  East North Central
# 3                     Graduate degree      South Atlantic
# 4                     Bachelor degree         New England
# 5                     Graduate degree     Middle Atlantic
# 6    Some college or Associate degree  West South Central
# ..                                ...                 ...
# 543                   Bachelor degree             Pacific
# 544                   Bachelor degree  West North Central
# 545                   Graduate degree             Pacific
# 546                High school degree      South Atlantic
# 548  Some college or Associate degree      South Atlantic
#
# [331 rows x 15 columns]

# %%
# Now we can check again:
cleaned_table.isnull().any(axis = 1).sum()
# Out:
# 0

# %% [markdown]
# #### Fill Null Values with a Placeholder
#
# We can also replace all missing (null) values in the `survey` DataFrame with something using `fillna()`:
#
# ```python
# # Replace all null (NaN) values in the DataFrame with the string 'bruh'
# survey = survey.fillna('bruh')

# %%
# Fill all null values:

survey = survey.fillna('bruh')

survey
# Out:
#                ID     Answer   smoking   alcohol  gambling skydiving  \
# 0            bruh   Response  Response  Response  Response  Response
# 1    3237565956.0  Lottery B      bruh      bruh      bruh      bruh
# 2    3234982343.0  Lottery A        No       Yes        No        No
# 3    3234973379.0  Lottery A        No       Yes       Yes        No
# 4    3234972383.0  Lottery B       Yes       Yes       Yes        No
# ..            ...        ...       ...       ...       ...       ...
# 546  3234761827.0  Lottery B        No        No        No        No
# 547  3234761718.0  Lottery A        No       Yes        No       Yes
# 548  3234761071.0  Lottery A       Yes       Yes       Yes        No
# 549  3234760930.0  Lottery A        No       Yes       Yes        No
# 550  3234760413.0  Lottery B       Yes       Yes       Yes        No
#
#      speeding   cheated     steak steak_preference    gender       age  \
# 0    Response  Response  Response         Response  Response  Response
# 1        bruh      bruh      bruh             bruh      bruh      bruh
# 2          No        No       Yes      Medium rare      Male      > 60
# 3         Yes       Yes       Yes             Rare      Male      > 60
# 4         Yes       Yes       Yes           Medium      Male      > 60
# ..        ...       ...       ...              ...       ...       ...
# 546       Yes        No       Yes      Medium rare    Female     18-29
# 547       Yes        No        No             bruh    Female      > 60
# 548       Yes        No       Yes      Medium rare      Male     30-44
# 549       Yes       Yes        No             bruh    Female     45-60
# 550       Yes        No       Yes           Medium      Male     18-29
#
#                 income                         education              region
# 0             Response                          Response            Response
# 1                 bruh                              bruh                bruh
# 2    $50,000 - $99,999  Some college or Associate degree  East North Central
# 3            $150,000+                   Graduate degree      South Atlantic
# 4    $50,000 - $99,999                   Bachelor degree         New England
# ..                 ...                               ...                 ...
# 546  $25,000 - $49,999                High school degree      South Atlantic
# 547  $50,000 - $99,999  Some college or Associate degree            Mountain
# 548  $50,000 - $99,999  Some college or Associate degree      South Atlantic
# 549  $50,000 - $99,999  Some college or Associate degree             Pacific
# 550       $0 - $24,999                              bruh            Mountain
#
# [551 rows x 15 columns]
