# %% [markdown]
# ## Week 7 Demo: Inference
# #### This demo is adapted from D6.

# %% [markdown]
# First, impoart packages needed and import our data:

# %%
# Import seaborn and apply its plotting styles
import seaborn as sns
sns.set(font_scale=2, style="white")

# import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# set plotting size parameter
plt.rcParams['figure.figsize'] = (17, 7)
import logging
import matplotlib
matplotlib.set_loglevel("error")  # or "critical"

# import pandas & numpy library
import pandas as pd
import numpy as np

# Statmodels
import statsmodels
import statsmodels.formula.api as smf

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

pulitzer = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/pulitzer/pulitzer-circulation-data.csv')

# %%
pulitzer.head()
# Out:
#              Newspaper Daily Circulation, 2004 Daily Circulation, 2013  \
# 0            USA Today               2,192,098               1,674,306
# 1  Wall Street Journal               2,101,017               2,378,827
# 2       New York Times               1,119,027               1,865,318
# 3    Los Angeles Times                 983,727                 653,868
# 4      Washington Post                 760,034                 474,767
#
#   Change in Daily Circulation, 2004-2013  \
# 0                                   -24%
# 1                                   +13%
# 2                                   +67%
# 3                                   -34%
# 4                                   -38%
#
#    Pulitzer Prize Winners and Finalists, 1990-2003  \
# 0                                                1
# 1                                               30
# 2                                               55
# 3                                               44
# 4                                               52
#
#    Pulitzer Prize Winners and Finalists, 2004-2014  \
# 0                                                1
# 1                                               20
# 2                                               62
# 3                                               41
# 4                                               48
#
#    Pulitzer Prize Winners and Finalists, 1990-2014
# 0                                                2
# 1                                               50
# 2                                              117
# 3                                               85
# 4                                              100

# %%
# Let's take a look at the data types:

pulitzer.dtypes
# Out:
# Newspaper                                          object
# Daily Circulation, 2004                            object
# Daily Circulation, 2013                            object
# Change in Daily Circulation, 2004-2013             object
# Pulitzer Prize Winners and Finalists, 1990-2003     int64
# Pulitzer Prize Winners and Finalists, 2004-2014     int64
# Pulitzer Prize Winners and Finalists, 1990-2014     int64
# dtype: object

# %% [markdown]
# From the dataset above, we can see that the numbers in daily circulation are all in string type and are separated with commas. In order to perform numerical analysis, we will need to remove the commas and convert the strings to floats.
#
# `.str.replace(',', '')` can be used to remove all commas from the strings in this column. This is necessary because numeric values formatted as strings often use commas as thousands separators, which need to be eliminated for numerical operations.

# %%
#get rid of the commas in the numbers for Daily Circulation

pulitzer['Daily Circulation, 2004'] = pulitzer['Daily Circulation, 2004'].str.replace(',', '').astype(float)

pulitzer['Daily Circulation, 2013'] = pulitzer['Daily Circulation, 2013'].str.replace(',', '').astype(float)
pulitzer['Change in Daily Circulation, 2004-2013'] = pulitzer['Change in Daily Circulation, 2004-2013'].str.replace('%', '').astype(float)

# %%
# Now take another look:

pulitzer.dtypes
# Out:
# Newspaper                                           object
# Daily Circulation, 2004                            float64
# Daily Circulation, 2013                            float64
# Change in Daily Circulation, 2004-2013             float64
# Pulitzer Prize Winners and Finalists, 1990-2003      int64
# Pulitzer Prize Winners and Finalists, 2004-2014      int64
# Pulitzer Prize Winners and Finalists, 1990-2014      int64
# dtype: object

# %% [markdown]
# Then let's take a look at daily circulation distribution in 2004 and in 2013.
#
# In order to observe distributions, we can use histograms.
#
# To better compare the distributions, we can use plt.subplots to plots two plots together.

# %% [markdown]
# In cell below, we're using `matplotlib`'s playful **xkcd** sketch-style visualization to compare the distribution of daily newspaper circulation in two different years.
#
# #### What the code does:
# - Activates `plt.xkcd()` mode to give the plots a hand-drawn comic look.
# - Creates a figure with **two subplots**, side-by-side, sharing the same y-axis.
# - The **left subplot** shows a histogram of `'Daily Circulation, 2004'`.
# - The **right subplot** shows a histogram of `'Daily Circulation, 2013'`.
# - Both histograms use **40 bins** and a consistent **color (`dimgrey`)** to allow easy comparison.
# - X-axis labels are removed to reduce clutter, as the titles already indicate the year.

# %%
# Let's set the style to 'xkcd' just for fun :)
with plt.xkcd():
    # Creating a figure and a pair of subplots with shared Y-axis
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)

    # Plotting a histogram for 'Daily Circulation, 2004' on the first subplot (ax1)
    sns.histplot(pulitzer['Daily Circulation, 2004'], ax=ax1, bins=40, color="dimgrey")
    # Setting the title for the first subplot to 'Daily Circulation, 2004'
    ax1.set_title('Daily Circulation, 2004')
    # Clearing the x-label for the first subplot as it's self-explanatory or not needed
    ax1.set_xlabel('')

    # Plotting a histogram for 'Daily Circulation, 2013' on the second subplot (ax2)
    sns.histplot(pulitzer['Daily Circulation, 2013'], ax=ax2, bins=40, color="dimgrey")
    # Setting the title for the second subplot to 'Daily Circulation, 2013'
    ax2.set_title('Daily Circulation, 2013')
    # Clearing the x-label for the second subplot as well
    ax2.set_xlabel('')

# %% [markdown]
# Now let's take a look at the distribution of *change* in daily circulation from 2004-2013:

# %%
# Creating a histogram for the 'Change in Daily Circulation, 2004-2013' column in the 'pulitzer' DataFrame
with plt.xkcd():
    sns.histplot(pulitzer['Change in Daily Circulation, 2004-2013'],
                 kde=False,  # Disabling the Kernel Density Estimate (KDE) plot overlay
                 bins=30,    # Setting the number of bins in the histogram to 30
                 color="dimgrey");  # Setting the color of the histogram bars to dim grey
    plt.show()

# Note: The semicolon at the end is often used in Python (especially in Jupyter notebooks) 
# to suppress unwanted output, not needed in scripts.

# The kde=False parameter specifies that the kernel density estimate, which is a smooth 
# curve representing the data distribution, should not be included in the plot.

# %%
# Let's see what happens when we have kde = True:
with plt.xkcd():
    sns.histplot(pulitzer['Change in Daily Circulation, 2004-2013'],
                 kde=True,  # Enabling the Kernel Density Estimate (KDE) plot overlay
                 bins=30,    # Setting the number of bins in the histogram to 30
                 color="dimgrey");  # Setting the color of the histogram bars to dim grey
    plt.show()

    # You will see a smooth line representing the distribution of your data.

# %% [markdown]
# We can see from the histrogram that we have a paper with very great positive change in daily circulation. Let'e find which one it is:

# %%
# determine which paper has a positive change in circulation much larger than other papers

pulitzer[pulitzer['Change in Daily Circulation, 2004-2013'] > 30]
# Out:
#         Newspaper  Daily Circulation, 2004  Daily Circulation, 2013  \
# 2  New York Times                1119027.0                1865318.0
#
#    Change in Daily Circulation, 2004-2013  \
# 2                                    67.0
#
#    Pulitzer Prize Winners and Finalists, 1990-2003  \
# 2                                               55
#
#    Pulitzer Prize Winners and Finalists, 2004-2014  \
# 2                                               62
#
#    Pulitzer Prize Winners and Finalists, 1990-2014
# 2                                              117

# %% [markdown]
# In cells below, we use `seaborn.lmplot` to create a scatter plots with a **linear regression line**, visualized in the playful `xkcd()` comic style.
#
# ### Plot Details:
# - **X-axis**: Number of Pulitzer Prize winners and finalists between **1990–2003**.
# - **Y-axis**: Number of Pulitzer Prize winners and finalists between **2004–2014**.
# - The goal is to examine whether there's a relationship between a newspaper's past Pulitzer performance and its future performance.
#
# #### Why is this plot useful?
# This can reveal whether newspapers that were successful in the earlier period continued to perform well in the later decade. A strong linear trend would suggest consistency or institutional prestige in winning Pulitzers.
#
# ### Styling:
# - `plt.xkcd()` gives the plot a hand-drawn, comic-like aesthetic.
# - `fit_reg=True` includes a regression line to highlight the trend.
# - The plot uses a height of 6 and an aspect ratio of 2 for better readability.

# %%
with plt.xkcd():
    # Creating a scatter plot using seaborn's lmplot function
    sns.lmplot(x = 'Pulitzer Prize Winners and Finalists, 1990-2003',  # Setting the x-axis to represent data from 1990-2003
               y = 'Pulitzer Prize Winners and Finalists, 2004-2014',  # Setting the y-axis to represent data from 2004-2014
               data = pulitzer,  # Specifying the DataFrame 'pulitzer' as the source of data
               fit_reg = False,  # Disabling the regression line, since this is a scatter plot only
               height = 6,  # Setting the height of the plot
               aspect=2)  # Setting the aspect ratio (width = 2 * height)

    # Setting the labels for x and y axes
    plt.xlabel('1990-2003')
    plt.ylabel('2004-2014')

    # Adding a title to the plot
    plt.title('Pulitzer Prize Winners and Finalists');
    plt.show()

# %%
with plt.xkcd():
    # Creating a scatter plot using seaborn's lmplot function
    sns.lmplot(x = 'Pulitzer Prize Winners and Finalists, 1990-2003',  # Setting the x-axis to represent data from 1990-2003
               y = 'Pulitzer Prize Winners and Finalists, 2004-2014',  # Setting the y-axis to represent data from 2004-2014
               data = pulitzer,  # Specifying the DataFrame 'pulitzer' as the source of data
               fit_reg = True,  # Let's enable the regression fit.
               height = 6,  # Setting the height of the plot
               aspect=2)  # Setting the aspect ratio (width = 2 * height)

    # Setting the labels for x and y axes
    plt.xlabel('1990-2003')
    plt.ylabel('2004-2014')

    # Adding a title to the plot
    plt.title('Pulitzer Prize Winners and Finalists');
    plt.show()

# %% [markdown]
# What you should see here is that there appears to be some general positive relationship but note that there are outliers in circulation, where circulation is much higher than number of Pulitzers won as well as outliers in Pulitzers won. Overall, most of the data are clustered around zero Pulitzers. This is because the distributions of both of our variables are skewed right. This suggests that we may need to transform these data to use linear regression to ensure that the large outlier values are not driving our relationship.

# %% [markdown]
# As discussed in class, we're applying a `log10` transformation to the Pulitzer Prize count data. This transformation helps normalize the data and reduce the influence of extremely large values.
#
# We'll use an **offset of 0.1** to avoid taking the logarithm of zero (which is undefined) and to prevent extreme compression of low values.
#
# #### Why use an offset?
#
# The offset helps us avoid two issues:
#
# 1. **Log(0) is undefined**: If any Pulitzer counts are exactly zero, applying `log10` directly would cause a math error.
# 2. **Better spread of small values**: Using a small offset like 0.1 (rather than 1) prevents low values from collapsing too close to zero on the log scale, preserving some variation.

# %%
# log transform with a 0.1 offset

pulitzer['pulitzer_log10'] = np.log10(pulitzer['Pulitzer Prize Winners and Finalists, 1990-2014'] + 0.1)

# %%
# visualize the distribtuion of the log10 column
with plt.xkcd():
    sns.histplot(pulitzer['pulitzer_log10'], bins=30, color="dimgrey")
    ax1.set_xlabel('1990-2003')
    ax1.set_ylabel('Number of Pulitzers');
    plt.show()

# %% [markdown]
# Let's observe the relationship again:

# %%
with plt.xkcd():
    sns.lmplot(x = 'pulitzer_log10',
               y = 'Change in Daily Circulation, 2004-2013',
               data = pulitzer, 
               fit_reg = True, 
               height = 6,
               aspect = 2, 
               line_kws={'color': 'red'},
               scatter_kws={'color': 'red'})
    plt.xlabel('Pulitzer winners and finalists (1990-2014)', size=18)
    plt.ylabel('Change in print and digital circulation (2004-2013)', size=18)
    plt.title('');
    plt.show()

# %% [markdown]
# And let's perform a linear regression:

# %% [markdown]
# In this analysis, we’re examining whether the number of Pulitzer Prizes a newspaper has won (on a log10 scale) is associated with changes in its **daily circulation** between 2004 and 2013.
#
# We will:
#
# 1. **Subsets relevant columns** from the `pulitzer` DataFrame:
#    - `'Change in Daily Circulation, 2004-2013'`: the response variable.
#    - `'pulitzer_log10'`: the predictor variable, log-transformed with an offset.
#
# 2. **Renames the columns** to simplify model syntax:
#    - `circulation`: change in readership.
#    - `pulitzer_log10`: log-scaled Pulitzer count.
#
# 3. **Fits a linear regression model** using `statsmodels.formula.api.ols`:
#    ```python
#    res_1 = smf.ols("circulation ~ pulitzer_log10", data=df).fit()
#    ```

# %%
df = pulitzer[['Change in Daily Circulation, 2004-2013', 
                         'pulitzer_log10']]
df.columns = ['circulation', 'pulitzer_log10']
df.head()

res_1 = smf.ols("circulation ~ pulitzer_log10", data=df).fit()

# Check out the results
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            circulation   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     2.800
# Date:                Fri, 16 May 2025   Prob (F-statistic):              0.101
# Time:                        11:27:30   Log-Likelihood:                -233.94
# No. Observations:                  50   AIC:                             471.9
# Df Residuals:                      48   BIC:                             475.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        -35.1237      5.164     -6.802      0.000     -45.506     -24.741
# pulitzer_log10     8.3256      4.975      1.673      0.101      -1.678      18.329
# ==============================================================================
# Omnibus:                        6.971   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):               11.514
# Skew:                           0.153   Prob(JB):                      0.00316
# Kurtosis:                       5.331   Cond. No.                         2.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### What did you see?

# %% [markdown]
# #### Statistical Significance:
# - **p-value for `pulitzer_log10`**: 0.101
#   This is **not statistically significant** at the 0.05 level, meaning we *cannot confidently conclude* that Pulitzer count predicts circulation change in this sample.
#
# - **R-squared**: 0.055
#   Only about 5.5% of the variance in circulation change is explained by Pulitzer count. The model has limited explanatory power.
#
# #### Final Notes:
# - While the trend is in the expected direction (more Pulitzers = less circulation loss), the result is not statistically significant.
# - Consider adding more variables (e.g. ownership, digital presence) or examining subgroups to better explain the variation in circulation change.
